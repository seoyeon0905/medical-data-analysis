# %% [markdown]
# <a href="https://colab.research.google.com/github/seoyeon0905/medical-data-analysis/blob/main/python/01_basic_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "age": [25, 34, 45, 52, 63, 29, 41],
    "gender": ["F", "M", "F", "M", "F", "F", "M"],
    "systolic_bp": [120, 130, 140, 135, 150, 125, 145]
}

df = pd.DataFrame(data)
df
# Out:
#    age gender  systolic_bp
# 0   25      F          120
# 1   34      M          130
# 2   45      F          140
# 3   52      M          135
# 4   63      F          150
# 5   29      F          125
# 6   41      M          145

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          7 non-null      int64
#  1   gender       7 non-null      object
#  2   systolic_bp  7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes
#              age  systolic_bp
# count   7.000000     7.000000
# mean   41.285714   135.000000
# std    13.350584    10.801234
# min    25.000000   120.000000
# 25%    31.500000   127.500000
# 50%    41.000000   135.000000
# 75%    48.500000   142.500000
# max    63.000000   150.000000

# %%
sns.histplot(df["age"])
plt.title("Age Distribution")
plt.show()
